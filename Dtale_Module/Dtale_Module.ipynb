# %% [markdown]
# # D-tale Module
# Particularly, we will be able to explore and wrangle your datasets via the graphical point-and-click interface. Here's what you can do:
# - import and export data;
# - sort, filter, format data;
# - create plots such as histograms, heatmaps, scatter plots, box plots, network analysis, etc.

# %%
import dtale
import pandas as pd
from pycaret.datasets import get_data # for import datasets
import warnings
warnings.filterwarnings("ignore")

# %%
df = get_data('wine')
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4        5  red
# 1      9.8        5  red
# ...

# %%
d = dtale.show(df)
d
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Tugra:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# - Code export from dtale tab on browser, and it works

# %%
import numpy as np
import pandas as pd

if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
    df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

corr_cols = [
'fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
'pH', 'sulphates', 'alcohol', 'quality'
]
corr_data = np.corrcoef(df[corr_cols].values, rowvar=False)
corr_data = pd.DataFrame(corr_data, columns=[corr_cols], index=[corr_cols])
corr_data.index.name = str('column')
corr_data = corr_data.reset_index()

# %%
corr_data
# Out:
#                  level_0 fixed acidity volatile acidity citric acid  \
# 0          fixed acidity      1.000000         0.219008    0.324436
# 1       volatile acidity      0.219008         1.000000   -0.377981
# 2            citric acid      0.324436        -0.377981    1.000000
# 3         residual sugar     -0.111981        -0.196011    0.142451
# 4              chlorides      0.298195         0.377124    0.038998
# 5    free sulfur dioxide     -0.282735        -0.352557    0.133126
# 6   total sulfur dioxide     -0.329054        -0.414476    0.195242
# 7                density      0.458910         0.271296    0.096154
# 8                     pH     -0.252700         0.261454   -0.329808
# 9              sulphates      0.299568         0.225984    0.056197
# 10               alcohol     -0.095452        -0.037640   -0.010493
# 11               quality     -0.076743        -0.265699    0.085532
#
#    residual sugar chlorides free sulfur dioxide total sulfur dioxide  \
# ...

# %%
# main statistics
stats = df['fixed acidity'].describe().to_frame().T
# sum
stats['sum'] = df['fixed acidity'].sum()
# median
stats['median'] = df['fixed acidity'].median()
# mode
mode = df['fixed acidity'].mode().values
stats['mode'] = np.nan if len(mode) > 1 else mode[0]
# var
stats['var'] = df['fixed acidity'].var()
# sem
stats['sem'] = df['fixed acidity'].sem()
uniq_vals = df['fixed acidity'].value_counts().sort_values(ascending=False)
uniq_vals.index.name = 'value'
uniq_vals.name = 'count'
uniq_vals = uniq_vals.reset_index()
uniq_vals.loc[:, 'type'] = 'float64'
sequential_diffs = df['fixed acidity'].diff()
#diff = diff[diff == diff]
min_diff = sequential_diffs.min()
max_diff = sequential_diffs.max()
avg_diff = sequential_diffs.mean()
diff_vals = sequential_diffs.value_counts().sort_values(ascending=False)

# %%
stats
# Out:
#                 count      mean       std  min  25%  50%  75%   max       sum  \
# fixed acidity  6497.0  7.215307  1.296434  3.8  6.4  7.0  7.7  15.9  46877.85
#
#                median  mode      var       sem
# fixed acidity     7.0   6.8  1.68074  0.016084

# %% [markdown]
# # Conclusion
#
# You can perform dtale functionality own your notebook. I enjoyed when i apply something on it. I will add some Screenshots in file, but you can follow links below and get experiment.
#
# Links about dtale:
#
# - Data professor youtube https://www.youtube.com/watch?v=jYlwwNycVh8&t=11s
# - dtale PyPI https://pypi.org/project/dtale/​
# - dtale GitHub https://github.com/man-group/dtale​
# - dtale live demo http://alphatechadmin.pythonanywhere.com/dtale/main/1
